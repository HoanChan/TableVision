# %%
# Tải dataset về - Tổng dung lượng tầm 90GB lận đó - Không tải nổi!
# !git clone https://huggingface.co/datasets/bsmock/pubtables-1m

# %%
# Lấy danh sách file từ url git của pubtables-1m
import requests
from bs4 import BeautifulSoup

url = "https://huggingface.co/datasets/bsmock/pubtables-1m"

response = requests.get(url)
if response.status_code == 200:
    html_content = response.text
    soup = BeautifulSoup(html_content, "html.parser")
    li_elements = soup.find_all("li")
    for li in li_elements:
        if li.text.startswith("PubTables-1M"):
            print(li.text)
else:
    print("Failed to retrieve HTML content.")
# Out:
# PubTables-1M-Structure_Filelists.tar.gz
# PubTables-1M-Structure_Annotations_Test.tar.gz: 93,834 XML files containing bounding boxes in PASCAL VOC format
# PubTables-1M-Structure_Annotations_Train.tar.gz: 758,849 XML files containing bounding boxes in PASCAL VOC format
# PubTables-1M-Structure_Annotations_Val.tar.gz: 94,959 XML files containing bounding boxes in PASCAL VOC format
# PubTables-1M-Structure_Images_Test.tar.gz
# PubTables-1M-Structure_Images_Train.tar.gz
# PubTables-1M-Structure_Images_Val.tar.gz
# PubTables-1M-Structure_Table_Words.tar.gz: Bounding boxes and text content for all of the words in each cropped table image
# PubTables-1M-Detection_Filelists.tar.gz
# PubTables-1M-Detection_Annotations_Test.tar.gz: 57,125 XML files containing bounding boxes in PASCAL VOC format
# PubTables-1M-Detection_Annotations_Train.tar.gz: 460,589 XML files containing bounding boxes in PASCAL VOC format
# ...

# %%
# Git-lfs là một công cụ để lưu trữ và truy xuất các tệp lớn trong git
# !git lfs install
# Out:
# Git LFS initialized.

# %%
# Xem dung lượng các thư mục con của thư mục hiện tại
# !du -h --max-depth=1
# Out:
# 120K	./.config
# 128K	.

# %%
# Xoá sạch mọi thứ
# !rm -rf *

# %%
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Structure_Filelists.tar.gz -P pubtables-1m
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Structure_Annotations_Test.tar.gz -P pubtables-1m
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Structure_Annotations_Train.tar.gz -P pubtables-1m
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Structure_Annotations_Val.tar.gz -P pubtables-1m
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Structure_Images_Test.tar.gz -P pubtables-1m
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Structure_Images_Train.tar.gz -P pubtables-1m
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Structure_Images_Val.tar.gz -P pubtables-1m
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Structure_Table_Words.tar.gz -P pubtables-1m

# %%
# !mkdir -p PubTables-1M-Structure/{images,train,test,val,words}
# !tar -xzvf PubTables-1M-Structure_Filelists.tar.gz --directory PubTables-1M-Structure/
# !tar -xzvf PubTables-1M-Structure_Annotations_Test.tar.gz --directory PubTables-1M-Structure/test/
# !tar -xzvf PubTables-1M-Structure_Annotations_Train.tar.gz --directory PubTables-1M-Structure/train/
# !tar -xzvf PubTables-1M-Structure_Annotations_Val.tar.gz --directory PubTables-1M-Structure/val/
# !tar -xzvf PubTables-1M-Structure_Images_Test.tar.gz --directory PubTables-1M-Structure/images/
# !tar -xzvf PubTables-1M-Structure_Images_Train.tar.gz --directory PubTables-1M-Structure/images/
# !tar -xzvf PubTables-1M-Structure_Images_Val.tar.gz --directory PubTables-1M-Structure/images/
# !tar -xzvf PubTables-1M-Structure_Table_Words.tar.gz --directory PubTables-1M-Structure/words/

# %%
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Detection_Filelists.tar.gz -P pubtables-1m
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Detection_Annotations_Test.tar.gz -P pubtables-1m
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Detection_Annotations_Train.tar.gz -P pubtables-1m
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Detection_Annotations_Val.tar.gz -P pubtables-1m
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Detection_Images_Test.tar.gz -P pubtables-1m
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Detection_Images_Train_Part1.tar.gz -P pubtables-1m
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Detection_Images_Train_Part2.tar.gz -P pubtables-1m
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Detection_Images_Val.tar.gz -P pubtables-1m
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Detection_Page_Words.tar.gz -P pubtables-1m

# %%
# !mkdir -p PubTables-1M-Detection/{images,train,test,val,words}
# !tar -xzvf PubTables-1M-Detection_Filelists.tar.gz --directory PubTables-1M-Detection/
# !tar -xzvf PubTables-1M-Detection_Annotations_Test.tar.gz --directory PubTables-1M-Detection/test/
# !tar -xzvf PubTables-1M-Detection_Annotations_Train.tar.gz --directory PubTables-1M-Detection/train/
# !tar -xzvf PubTables-1M-Detection_Annotations_Val.tar.gz --directory PubTables-1M-Detection/val/
# !tar -xzvf PubTables-1M-Detection_Images_Test.tar.gz --directory PubTables-1M-Detection/images/
# !tar -xzvf PubTables-1M-Detection_Images_Train_Part1.tar.gz --directory PubTables-1M-Detection/images/
# !tar -xzvf PubTables-1M-Detection_Images_Train_Part2.tar.gz --directory PubTables-1M-Detection/images/
# !tar -xzvf PubTables-1M-Detection_Images_Val.tar.gz  --directory PubTables-1M-Detection/images/
# !tar -xzvf PubTables-1M-Detection_Page_Words.tar.gz --directory PubTables-1M-Detection/words/

# %%
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/extract_structure_dataset.sh -P pubtables-1m
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Detection_Images_Test.tar.gz -P pubtables-1m
# !mkdir -p pubtables-1m/PubTables-1M-Detection/{images,train,test,val,words}
# !tar -xzf pubtables-1m/PubTables-1M-Detection_Images_Test.tar.gz --directory pubtables-1m/PubTables-1M-Detection/images/
# !wget https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Detection_Annotations_Test.tar.gz -P pubtables-1m
# !tar -xzf pubtables-1m/PubTables-1M-Detection_Annotations_Test.tar.gz --directory pubtables-1m/PubTables-1M-Detection/train/
# Out:
# --2023-11-06 09:02:45--  https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/extract_structure_dataset.sh
# Resolving huggingface.co (huggingface.co)... 65.8.178.93, 65.8.178.27, 65.8.178.118, ...
# Connecting to huggingface.co (huggingface.co)|65.8.178.93|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1982 (1.9K) [text/plain]
# Saving to: ‘pubtables-1m/extract_structure_dataset.sh’
#
# extract_structure_d 100%[===================>]   1.94K  --.-KB/s    in 0s
#
# 2023-11-06 09:02:45 (547 MB/s) - ‘pubtables-1m/extract_structure_dataset.sh’ saved [1982/1982]
#
# --2023-11-06 09:02:45--  https://huggingface.co/datasets/bsmock/pubtables-1m/resolve/main/PubTables-1M-Detection_Images_Test.tar.gz
# Resolving huggingface.co (huggingface.co)... 65.8.178.93, 65.8.178.27, 65.8.178.118, ...
# Connecting to huggingface.co (huggingface.co)|65.8.178.93|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import shutil
import matplotlib.pyplot as plt
import os
path = "F:/Python/Table Recognition/pubtables-1m/PubTables-1M-Structure"
files = open(os.path.join(path, "train_filelist.txt"),'r').read().splitlines() # lấy danh sách các file trong thư mục
files = [file.replace("train/", "images/").replace(".xml", ".jpg") for file in files]
fig, axes = plt.subplots(1, 5, figsize=(15, 3)) # tạo một figure với 5 subplots
for i, ax in enumerate(axes):
  img = plt.imread(os.path.join(path, files[i])) # đọc file ảnh thứ i
  ax.imshow(img) # hiển thị ảnh lên subplot thứ i
  ax.set_title(files[i]) # đặt tiêu đề cho subplot thứ i
  ## copy file ảnh vào thư mục images
  shutil.copyfile(os.path.join(path, files[i]), files[i].replace("images/", "sample/"))  

plt.show() # hiển thị figure

# %%
import os
path = "F:/Python/Table Recognition/pubtables-1m/PubTables-1M-Structure"
files = open(os.path.join(path, "train_filelist.txt"),'r').read().splitlines() # lấy danh sách các file trong thư mục
fname = os.path.join(path, files[5]) # đọc file ảnh thứ 0
file = open(fname, "r") # mở file xml
contents = file.read() # đọc nội dung file
print(contents)
# Out:
# <?xml version="1.0" ?>
# <annotation>
#    <folder/>
#    <filename>PMC2874801_table_0.jpg</filename>
#    <path>PMC2874801_table_0.jpg</path>
#    <source>
#       <database>PubTables1M-Structure</database>
#    </source>
#    <size>
#       <width>362</width>
#       <height>295</height>
#       <depth>3</depth>
#    </size>
#    <segmented>0</segmented>
#    <object>
#       <name>table</name>
#       <pose>Frontal</pose>
#       <truncated>0</truncated>
#       <difficult>0</difficult>
#       <occluded>0</occluded>
#       <bndbox>
#          <xmin>36.4271</xmin>
#          <ymin>36.4706</ymin>
#          <xmax>323.5075</xmax>
#          <ymax>256.5831</ymax>
#       </bndbox>
#    </object>
#    <object>
#       <name>table column header</name>
#       <pose>Frontal</pose>
#       <truncated>0</truncated>
#       <difficult>0</difficult>
#       <occluded>0</occluded>
#       <bndbox>
#          <xmin>36.4271</xmin>
#          <ymin>36.4706</ymin>
# ...

# %%
import os
import xml.etree.ElementTree as ET
class BoundingBox:
    def __init__(self, xmin, ymin, xmax, ymax):
        self.xmin = xmin
        self.ymin = ymin
        self.xmax = xmax
        self.ymax = ymax

class Size:
    def __init__(self, width, height, depth):
        self.width = width
        self.height = height
        self.depth = depth

class PVOC:
    def __init__(self, path, name, pose, truncated, difficult, occluded, xmin, ymin, xmax, ymax, width, height, depth, segmented):
        self.path = path
        self.name = name
        self.pose = pose
        self.truncated = truncated
        self.difficult = difficult
        self.occluded = occluded
        self.bndbox = BoundingBox( xmin = xmin, ymin = ymin, xmax = xmax, ymax = ymax )
        self.size = Size( width = width, height = height, depth = depth)
        self.segmented = segmented

def read_xml_files(folder_path):
    # Đường dẫn đến thư mục chứa các file XML
    path = folder_path

    # Kiểm tra xem đường dẫn thư mục tồn tại hay không
    if not os.path.exists(path):
        print(f"Thư mục '{path}' không tồn tại.")
        return []

    # Lấy danh sách các file XML trong thư mục
    xml_files = [f for f in os.listdir(path) if f.endswith('.xml')]

    objects = []  # Danh sách các đối tượng từ các file XML

    # Đọc nội dung của từng file XML và chuyển đổi thành đối tượng
    for xml_file in xml_files:
        # Đường dẫn đến file XML
        xml_path = os.path.join(path, xml_file)

        # Đọc nội dung file XML và tạo cây phân tích cú pháp
        tree = ET.parse(xml_path)
        root = tree.getroot()

        # Tạo đối tượng PVOC từ thông tin thu thập được
        obj = PVOC(
            path = "/content/pubtables-1m/PubTables-1M-Detection/images/" + root.find('filename').text,
            name = root.find('object/name').text,
            pose = root.find('object/pose').text,
            truncated = root.find('object/truncated').text,
            difficult = root.find('object/difficult').text,
            occluded = root.find('object/occluded').text,
            xmin = root.find('object/bndbox/xmin').text,
            ymin = root.find('object/bndbox/ymin').text,
            xmax = root.find('object/bndbox/xmax').text,
            ymax = root.find('object/bndbox/ymax').text,
            width = root.find('size/width').text,
            height = root.find('size/height').text,
            depth = root.find('size/depth').text,
            segmented = root.find('segmented').text
        )

        objects.append(obj)

    return objects


# Thay đổi folder_path thành đường dẫn thư mục chứa các file XML
folder_path = "/content/pubtables-1m/PubTables-1M-Detection/train"
objects = read_xml_files(folder_path)

# In thông tin các đối tượng
for obj in objects:
    print("Path:", obj.path)
    print("Name:", obj.name)
    print("Pose:", obj.pose)
    print("Truncated:", obj.truncated)
    print("Difficult:", obj.difficult)
    print("Occluded:", obj.occluded)
    print("Bounding Box:")
    print("  xmin:", obj.bndbox.xmin)
    print("  ymin:", obj.bndbox.ymin)
    print("  xmax:", obj.bndbox.xmax)
    print("  ymax:", obj.bndbox.ymax)
    print("Size:")
    print("  Width:", obj.size.width)
    print("  Height:", obj.size.height)
    print("  Depth:", obj.size.depth)
    print("Segmented:", obj.segmented)
    print("-----------------------------")
    break;
# Out:
# Path: /content/pubtables-1m/PubTables-1M-Detection/images/PMC5954789_3.jpg
# Name: table
# Pose: Frontal
# Truncated: 0
# Difficult: 0
# Occluded: 0
# Bounding Box:
#   xmin: 71.6189833653269
#   ymin: 128.1062683999883
#   xmax: 680.3544541465284
#   ymax: 300.3780653270152
# Size:
#   Width: 753
#   Height: 1000
#   Depth: 3
# Segmented: 0
# -----------------------------

# %%
import cv2
import matplotlib.pyplot as plt

def draw_bounding_boxes(images, indices):
    num_images = len(indices)
    fig, axes = plt.subplots(1, num_images, figsize=(15, 5))

    for i, index in enumerate(indices):
        image_info = images[index - 1]
        image_path = image_info.path
        image = cv2.imread(image_path)

        # Lấy thông tin bounding box
        xmin = float(image_info.bndbox.xmin)
        ymin = float(image_info.bndbox.ymin)
        xmax = float(image_info.bndbox.xmax)
        ymax = float(image_info.bndbox.ymax)

        # Vẽ bounding box lên ảnh
        cv2.rectangle(image, (int(xmin), int(ymin)), (int(xmax), int(ymax)), (0, 255, 0), 2)

        # Hiển thị ảnh với bounding box trên subplot tương ứng
        axes[i].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        axes[i].axis('off')

    plt.show()

# %%
import random
indices_to_draw = random.choices(range(len(objects)), k= 5)
print(indices_to_draw)
draw_bounding_boxes(objects, indices_to_draw)
# Out:
# [16954, 4297, 2817, 54402, 14193]

# %%
# Xây dựng dữ liệu để huấn luyện:
# File ảnh nằm ở images, tuy nhiên đường dẫn của nó cũng đã đuợc lưu trữ bên trong file xml
# File Xml được lưu trong train

# %%
# Mở file xml ngẫu nhiên từ thư mục train
import random
import os

data_directory = "F:/Python/Table Recognition/pubtables-1m/PubTables-1M-Structure/"
xml_filenames =  open(os.path.join(data_directory, "train_filelist.txt"),'r').read().splitlines()
xml_filename = random.choice(xml_filenames)
xml_path = os.path.join(data_directory, xml_filename)
print(xml_path)

# Đọc nội dung file xml
file = open(xml_path, "r")
contents = file.read()
print(contents)
# Out:
# F:/Python/Table Recognition/pubtables-1m/PubTables-1M-Structure/train/PMC3342648_table_1.xml
# <?xml version="1.0" ?>
# <annotation>
#    <folder/>
#    <filename>PMC3342648_table_1.jpg</filename>
#    <path>PMC3342648_table_1.jpg</path>
#    <source>
#       <database>PubTables1M-Structure</database>
#    </source>
#    <size>
#       <width>335</width>
#       <height>416</height>
#       <depth>3</depth>
#    </size>
#    <segmented>0</segmented>
#    <object>
#       <name>table</name>
#       <pose>Frontal</pose>
#       <truncated>0</truncated>
#       <difficult>0</difficult>
#       <occluded>0</occluded>
#       <bndbox>
#          <xmin>36.4991</xmin>
#          <ymin>36.5914</ymin>
#          <xmax>295.7713</xmax>
#          <ymax>376.9614</ymax>
#       </bndbox>
#    </object>
#    <object>
#       <name>table spanning cell</name>
#       <pose>Frontal</pose>
#       <truncated>0</truncated>
#       <difficult>0</difficult>
#       <occluded>0</occluded>
# ...

# %%
import os
import xml.etree.ElementTree as ET

class BoundingBox:
    def __init__(self, name, pose, truncated, difficult, occluded, xmin, ymin, xmax, ymax):
        self.name = name
        self.pose = pose
        self.truncated = truncated
        self.difficult = difficult
        self.occluded = occluded
        self.bbox = [xmin, ymin, xmax, ymax]

class Size:
    def __init__(self, width, height, depth):
        self.width = width
        self.height = height
        self.depth = depth

class PVOC:
    def __init__(self, path, size, segmented, bndboxes):
        self.path = path
        self.size = size
        self.segmented = segmented
        self.bndboxes = bndboxes

def readXML(xml_path):
    # Đọc nội dung file XML và tạo cây phân tích cú pháp
    tree = ET.parse(xml_path)
    root = tree.getroot()

    # Lấy thông tin chung
    size = Size(
        width=root.find('size/width').text,
        height=root.find('size/height').text,
        depth=root.find('size/depth').text
    )
    segmented = root.find('segmented').text

    # Tạo danh sách bounding boxes
    bndboxes = []

    for object_ in root.iter('object'):
        name = object_.find('name').text
        pose = object_.find('pose').text
        truncated = object_.find('truncated').text
        difficult = object_.find('difficult').text
        occluded = object_.find('occluded').text
        for box in object_.findall("bndbox"):
            xmin = float(box.find('xmin').text)
            ymin = float(box.find('ymin').text)
            xmax = float(box.find('xmax').text)
            ymax = float(box.find('ymax').text)
        bndboxes.append(BoundingBox(name, pose, truncated, difficult, occluded, xmin, ymin, xmax, ymax))

    # Tạo đối tượng PVOC
    obj = PVOC(
        path=root.find('filename').text,
        bndboxes=bndboxes,
        size=size,
        segmented=segmented
    )
    return obj

obj = readXML(xml_path)

print("Path:", obj.path) 
print("Size:")
print("  Width:", obj.size.width)
print("  Height:", obj.size.height)
print("  Depth:", obj.size.depth)
print("Segmented:", obj.segmented)
print("Bounding Boxes:")
for bndbox, i in zip(obj.bndboxes, range(len(obj.bndboxes))):
    print('  box', i + 1, ":", bndbox.name, bndbox.pose, bndbox.truncated, bndbox.difficult, bndbox.occluded, bndbox.bbox)
# Out:
# Path: PMC3342648_table_1.jpg
# Size:
#   Width: 335
#   Height: 416
#   Depth: 3
# Segmented: 0
# Bounding Boxes:
#   box 1 : table Frontal 0 0 0 [36.4991, 36.5914, 295.7713, 376.9614]
#   box 2 : table spanning cell Frontal 0 0 0 [36.4991, 36.5914, 61.763, 68.7345]
#   box 3 : table spanning cell Frontal 0 0 0 [61.763, 36.5914, 185.7597, 51.5795]
#   box 4 : table spanning cell Frontal 0 0 0 [185.7597, 36.5914, 295.7713, 51.5795]
#   box 5 : table column header Frontal 0 0 0 [36.4991, 36.5914, 295.7713, 68.7345]
#   box 6 : table row Frontal 0 0 0 [36.4991, 36.5914, 295.7713, 51.5795]
#   box 7 : table row Frontal 0 0 0 [36.4991, 51.5795, 295.7713, 68.7345]
#   box 8 : table row Frontal 0 0 0 [36.4991, 68.7345, 295.7713, 84.2265]
#   box 9 : table row Frontal 0 0 0 [36.4991, 84.2265, 295.7713, 98.9323]
#   box 10 : table row Frontal 0 0 0 [36.4991, 98.9323, 295.7713, 113.6381]
#   box 11 : table row Frontal 0 0 0 [36.4991, 113.6381, 295.7713, 128.3439]
# ...

# %%
# Mở file xml ngẫu nhiên từ thư mục train
import random
import os

data_directory = "F:/Python/Table Recognition/pubtables-1m/PubTables-1M-Detection/"
xml_filenames =  open(os.path.join(data_directory, "train_filelist.txt"),'r').read().splitlines()
xml_filename = random.choice(xml_filenames)
xml_path = os.path.join(data_directory, xml_filename)
print(xml_path)

# Đọc nội dung file xml
file = open(xml_path, "r")
contents = file.read()
print(contents)
# Out:
# F:/Python/Table Recognition/pubtables-1m/PubTables-1M-Detection/train/PMC6334937_6.xml
# <?xml version="1.0" ?>
# <annotation>
#    <folder/>
#    <filename>PMC6334937_6.jpg</filename>
#    <path>PMC6334937_6.jpg</path>
#    <source>
#       <database>PubTables1M-Detection</database>
#    </source>
#    <size>
#       <width>773</width>
#       <height>1000</height>
#       <depth>3</depth>
#    </size>
#    <segmented>0</segmented>
#    <object>
#       <name>table</name>
#       <pose>Frontal</pose>
#       <truncated>0</truncated>
#       <difficult>0</difficult>
#       <occluded>0</occluded>
#       <bndbox>
#          <xmin>45.411764705882355</xmin>
#          <ymin>116.33267065491339</ymin>
#          <xmax>700.2139892578125</xmax>
#          <ymax>205.31640871606692</ymax>
#       </bndbox>
#    </object>
# </annotation>

# %%
# Mở file xml ngẫu nhiên từ thư mục train
import random
import os

data_directory = "F:\Python\Table Recognition\pubtables-1m\PubTables-1M-PDF-Annotations"
xml_filenames =  os.listdir(data_directory)
xml_filename = random.choice(xml_filenames)
xml_path = os.path.join(data_directory, xml_filename)
print(xml_path)

# Đọc nội dung file xml
file = open(xml_path, "r")
contents = file.read()
print(contents)
# Out:
# F:\Python\Table Recognition\pubtables-1m\PubTables-1M-PDF-Annotations\PMC4875960_tables.json
# [
#     {
#         "cells": [
#             {
#                 "row_nums": [
#                     0
#                 ],
#                 "column_nums": [
#                     0
#                 ],
#                 "align": "unknown",
#                 "style": "none",
#                 "indented": false,
#                 "is_column_header": true,
#                 "pdf_bbox": [
#                     178.58009338378906,
#                     663.6111450195312,
#                     351.63616943359375,
#                     672.7822265625
#                 ],
#                 "pdf_text_tight_bbox": null,
#                 "is_projected_row_header": false,
#                 "xml_text_content": "",
#                 "xml_raw_text_content": "",
#                 "pdf_text_content": ""
#             },
#             {
#                 "row_nums": [
#                     0
# ...
