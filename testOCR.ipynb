# %%
from utils.cv import *
image = cv2.imread("sample/ocr/ocr4.png")
lines = cut_text_line(image)
lines = [(line, str(i)) for i, line in enumerate(lines)]
display_images_with_labels([(image, 'img')] + lines, (2,len(lines)//2+1), (10,1))

# %%
from utils.cv import *
image = cv2.imread("sample/ocr/ocr1.png")
lines = cut_text_line(image)
lines = [(line, str(i)) for i, line in enumerate(lines)]
display_images_with_labels([(image, 'img')] + lines, (2,len(lines)//2+1), (10,1))

# %%
from utils.cv import *
image = cv2.imread("sample/ocr/ocr2.png")
lines = cut_text_line(image)
lines = [(line, str(i)) for i, line in enumerate(lines)]
display_images_with_labels([(image, 'img')] + lines, (2,len(lines)//2+1), (10,1))

# %%
from utils.cv import *
image = cv2.imread("sample/ocr/ocr3.png")
lines = cut_text_line(image)
eimg = np.zeros((800, 600, 3), dtype=np.uint8)
lines = [((line if len(line) > 0 else eimg), str(i)) for i, line in enumerate(lines) ]
display_images_with_labels([(image, 'img')] + lines, (len(lines)//2+1, 2), (10,1))

# %%
from utils.ocr import *

detector = init_VietOCR()
# Out:
# Đã cài đặt thư viện nhận diện văn bản
# /home/codespace/.python/current/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Model weight /tmp/vgg_seq2seq.pth exsits. Ignore download!

# %%
from utils.ocr import detectText
image = cv2.imread("sample/ocr/ocr3.png")
text, lines = detectText(image, detector)
print(text)
# Out:
# II. Tài sán cố định
# Thi thi sản cô định hữnh
# Nguyên giá
# Giá trị hao môn lũy kê
# Tái sân cô định thuê tài chính
# Nguyên giá
# Giá vị hao môn lũy kê
